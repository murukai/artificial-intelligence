# %%
import pandas as pd

# %%
car = pd.read_csv('~/work/data/cars.csv')

# %%
vc = car[car.Make == 'Mercedes-Benz'].Type.value_counts()

# %%
# %matplotlib inline

# %%
vc.plot.pie()

# %%
import matplotlib.pyplot as plt

# %%
vc.values
# Out:
# array([16,  5,  3,  2])

# %%
vc.index
# Out:
# Index(['Sedan', 'Sports', 'Wagon', 'SUV'], dtype='object')

# %%
print('{:1.1f}%'.format(1.234555))
print('%1.1f%%'%(1.234555))
# Out:
# 1.2%
# 1.2%

# %%
plt.pie(x = vc.values, 
        labels = vc.index,)
plt.show()

# %%
plt.figure(figsize = (8,10))
vc.plot.pie(cmap = 'Set2',
        radius = 1,
       autopct = 'perc %1.1f %%', 
      explode = [0.1,0.05,0.01,0.001], shadow = True,
       wedgeprops = {'edgecolor' : 'black', 'linewidth' : 5, 'width' : .5,},
   textprops= {'size' : 15},  )
plt.title('Type of Cars made by Mercedez\n', fontsize = 20, color = 'darkred' , weight = 'bold')
plt.show()

# %%
print(plt.colormaps())
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r
# ...

# %% [markdown]
# ## count for all the types of cars - Bar plot

# %%
vc.plot.bar(figsize = (10,5))
plt.title("Types of cars made by 'Mercedes-Benz'\n", fontsize = 30)
plt.xlabel('Type', fontsize = 20)
plt.ylabel('Count', fontsize = 20)
plt.xticks(fontsize = 15, rotation = 0)
plt.yticks(fontsize = 15)
#plt.annotate('String Annotate' , xy = (2,10), fontsize = 20, color = 'seagreen', weight = 'bold')
for i in range(len(vc)):
    plt.annotate(vc[i],xy=(i,vc[i]), fontsize = 15, color = 'seagreen', weight = 'bold')
#plt.plot([0,3],[0,15])
#plt.plot([0,2],[10,10])
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize = (10,5))
sns.countplot('Type', data = car[car.Make == 'Mercedes-Benz'], order = vc.index, palette = 'Set2' )
plt.title("Types of cars made by 'Mercedes-Benz'\n", fontsize = 30)
plt.xlabel('Type', fontsize = 20)
plt.ylabel('Count', fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.annotate('String Annotate' , xy = (2,10), fontsize = 20, color = 'seagreen', weight = 'bold')
for i in range(len(vc)):
    plt.annotate(vc[i],xy=(i,vc[i]), fontsize = 15, color = 'seagreen', weight = 'bold')
#plt.plot([0,3],[0,15])
#plt.plot([0,2],[10,10])
plt.show()

# %% [markdown]
# ## subplots

# %%
f, axes = plt.subplots(2,2, figsize = (20,8))

# %%
f

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3b6a5e1358>,
# ...
#       dtype=object)

# %%
f, axes = plt.subplots(1,2, figsize = (20,5))

# %%
x = car.MPG_City
y = car.MPG_Highway

# %%
f, axes = plt.subplots(2,2, figsize = (20,5))
axes[1,0].scatter(x,y)
axes[1,0].annotate('Annotate', xy = (45,45))
# Out:
# Text(45, 45, 'Annotate')

# %%
f, axes = plt.subplots(1,2, figsize = (20,5))
sns.countplot('Type', data = car[car.Make == 'Mercedes-Benz'], order = vc.index, palette = 'Set2' , ax = axes[0])
vc.plot.pie(cmap = 'Set2',
        radius = 1,
       autopct = 'perc %1.1f %%', 
      explode = [0.1,0.05,0.01,0.001], shadow = True,
       wedgeprops = {'edgecolor' : 'black', 'linewidth' : 5, 'width' : .5,},
   textprops= {'size' : 15}, ax = axes[1] )
axes[0].annotate('axes[0,0]', xy = (2,4))
plt.show()

# %%
pd.crosstab(car.Type, car.Make)
# Out:
# Make    Acura  Audi  BMW  Buick  Cadillac  Chevrolet  Chrysler  Dodge  Ford  \
# Type
# Hybrid      0     0    0      0         0          0         0      0     0
# SUV         1     0    2      2         2          4         0      1     4
# Sedan       5    13   13      7         4         15        13      8    11
# Sports      1     4    4      0         1          2         1      1     3
# Truck       0     0    0      0         1          5         0      3     3
# Wagon       0     2    1      0         0          1         1      0     2
#
# Make    GMC  ...  Pontiac  Porsche  Saab  Saturn  Scion  Subaru  Suzuki  \
# Type         ...
# Hybrid    0  ...        0        0     0       0      0       0       0
# SUV       3  ...        1        1     0       1      0       0       2
# Sedan     1  ...        8        0     6       6      1       6       5
# Sports    0  ...        1        6     0       0      0       2       0
# ...

# %%
top10 = car.Make.value_counts()[:10]
top10
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Volkswagen       15
# Chrysler         15
# Name: Make, dtype: int64

# %%
pd.crosstab(car[car.Make.isin(top10.index)].Make , car[car.Make.isin(top10.index)].Type)
# Out:
# Type           Hybrid  SUV  Sedan  Sports  Truck  Wagon
# Make
# Audi                0    0     13       4      0      2
# BMW                 0    2     13       4      0      1
# Chevrolet           0    4     15       2      5      1
# Chrysler            0    0     13       1      0      1
# Ford                0    4     11       3      3      2
# Honda               2    3     11       1      0      0
# Mercedes-Benz       0    2     16       5      0      3
# Nissan              0    3      9       2      2      1
# Toyota              1    5     16       2      3      1
# Volkswagen          0    1     11       0      0      3

# %%
top3 = car.Type.value_counts()[:3]

# %%
make = car[car.Make.isin(top10.index) & (car.Type.isin(top3.index))].Make
typ  = car[car.Make.isin(top10.index) & (car.Type.isin(top3.index))].Type

# %%
pd.crosstab(make,typ).plot.bar(figsize = (18,5), stacked = True)

# %%
plt.figure(figsize = (15,5))
sns.countplot(x ='Make', hue = 'Type',
              data = car[car.Make.isin(top10.index) & (car.Type.isin(top3.index))] )

# %% [markdown]
# ## Histograms and distribution plots

# %%
d = car[car.Make.isin(top10.index) & (car.Type.isin(top3.index))]

# %%
d.MSRP.describe()
# Out:
# count       176.000000
# mean      33889.517045
# std       20113.033812
# min       10760.000000
# 25%       21836.250000
# 50%       27962.500000
# 75%       38931.250000
# max      128420.000000
# Name: MSRP, dtype: float64

# %%
plt.figure(figsize = (10,5))
d.MSRP.plot.hist(bins = 50, edgecolor = 'black', color = 'white')
plt.show()

# %% [markdown]
# ## continous probabilty distribution plot

# %% [markdown]
# #### Bell curve`

# %%
plt.figure(figsize = (10,5))
sns.distplot(car.MSRP, hist = False)
plt.xlabel('MSRP')
plt.ylabel('pdf')
# Out:
# Text(0, 0.5, 'pdf')

# %%
top10
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Volkswagen       15
# Chrysler         15
# Name: Make, dtype: int64

# %%
c  = ['red','orange','green','navy','skyblue','pink','magenta','aqua','darkred','seagreen']
plt.figure(figsize =(15,5))
for i in range(5):
    sns.distplot(car[car.Make== top10.index[i]].MSRP, hist = False, color = c[i], label = top10.index[i])

# %%
car[car.Make.isin(top10.index[:5])].groupby('Make').agg(['mean','std'])['MSRP'].round(2)
# Out:
#                    mean       std
# Make
# BMW            43285.25  12459.76
# Chevrolet      26587.04  10887.94
# Ford           24015.87   7952.49
# Mercedes-Benz  60656.81  30508.76
# Toyota         22524.46   9022.43

# %% [markdown]
# # boxplot

# %%
plt.figure(figsize = (15,5))
sns.boxplot('MSRP', data = car)
#plt.plot([car.MSRP.mean(),car.MSRP.mean()],[car.MSRP.mean(),1], color = 'red')
plt.annotate('|', xy = (car.MSRP.mean(),0.5), color = 'red')
# Out:
# Text(32774.85514018692, 0.5, '|')

# %%
car.MSRP.mean()
# Out:
# 32774.85514018692

# %%
plt.figure(figsize = (15,5))
sns.boxplot('Length', data = car)

# %%
plt.figure(figsize = (15,5))
sns.boxplot(x = 'MSRP', y = 'Make' , data = car[car.Make.isin(top10.index[:5])])

# %%
q3 = car[car.Make=='Mercedes-Benz'].MSRP.quantile(0.75)
q1 = car[car.Make=='Mercedes-Benz'].MSRP.quantile(0.25)
iqr_out = q3 + 1.5 * (q3-q1)

# %%
plt.figure(figsize = (15,5))
sns.distplot( car[car.Make=='Mercedes-Benz'].MSRP)
