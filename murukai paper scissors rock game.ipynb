# %%
#importing the random randint to be used when making computer choice
from random import randint
# these are the game options
game_options = ['rock','paper','scissors']

# capturing the username of the person who is playing
player_name = input('Please enter your name : ')

playing_options = ['c','f']

play_against_computer = input('Do you want to play against computer or a friend c - computer or f - friend : ')
play_against_computer = play_against_computer.lower()
while True:
    if play_against_computer not in playing_options:
        play_against_computer = input('please choose  computer or a friend c - computer or f - friend : ')
    else:
        break

continue_game_options = ['y','n']

if play_against_computer == 'c':
    continue_game = input('Shall we begin ? y/n : ')
    while True :
        if continue_game not in continue_game_options:
             continue_game = input('please choose between y - yes or n - no : ')
        else :
            break
    
    while(continue_game == 'y'):
        player_choice = input("Make a choice between paper, scissors and rock ? : ")
        player_choice = player_choice.lower()
        while True:
            if player_choice not in game_options:
                player_choice = input("Make a choice between paper, scissors and rock ? :")
            else:
                break
        computer_choice = game_options[randint(0,2)]
        if player_choice == "paper" and computer_choice == 'rock':
            print('Wooow {} you have won the game...!!!!!!!!!!!!', player_name)
        elif player_choice == 'rock' and computer_choice == 'scissors':
            print('Wooow {} you have won the game...!!!!!!!!!!!!', player_name)
        elif player_choice == 'scissors' and computer_choice == 'paper':
            print('Wooow {} you have won the game...!!!!!!!!!!!!', player_name)
        else:
            print(':( sorry try again')
        continue_game = input('Shall we continue ? y/n : ')
        
        while True:
            if continue_game not in continue_game_options:
                continue_game = input('please choose between y - yes or n - no : ')
            else:
                break
else:
    second_player_name = input('Second player please enter your name : ')
    continue_game = input('{} shall we begin ? y/n : '.format(player_name))
    continue_game = continue_game.lower()
    while True:
        if continue_game not in continue_game_options:
            continue_game = input('please choose between y - yes or n - no : ')
        else:
            break

    while(continue_game == 'y'):
        player_choice = input("{} make a choice between paper, scissors and rock ? : ".format(player_name))
        player_choice = player_choice.lower()
        while True:
            if player_choice not in game_options:
                player_choice = input("{} make a choice between paper, scissors and rock ? : ".format(player_name))
            else:
                break
        
        second_player_choice = input("{} make a choice between paper, scissors and rock ? : ".format(second_player_name))
        second_player_choice = second_player_choice.lower()
        while True:
            if second_player_choice not in game_options:
                second_player_choice = input("{} make a choice between paper, scissors and rock ? : ".format(second_player_name))
            else:
                break
        
        if player_choice == "paper" and second_player_choice == 'rock':
            print('Wooow {} you have won the game...!!!!!!!!!!!!', player_name)
        elif player_choice == 'rock' and second_player_choice == 'scissors':
            print('Wooow {} you have won the game...!!!!!!!!!!!!', player_name)
        elif player_choice == 'scissors' and second_player_choice == 'paper':
            print('Wooow {} you have won the game...!!!!!!!!!!!!', player_name)
        else:
            print('Wooow {} you have won the game...!!!!!!!!!!!!', second_player_name)
        continue_game = input('Shall we continue ? y/n : ')
        continue_game = continue_game.lower()
        while True:
            if continue_game not in continue_game_options:
                continue_game = input('please choose between y - yes or n - no : ')
            else:
                break
# Out:
# Please enter your name : murukai
# Do you want to play against computer or a friend c - computer or f - friend : f
# f
# please choose between c - computer or f - friendhd
# hd
# please choose between c - computer or f - friendf
# f
